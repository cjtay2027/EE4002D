# %%
import os
import glob
import time
from datetime import datetime

import torch
import torch.nn as nn
from torch.distributions import MultivariateNormal
from torch.distributions import Categorical

import numpy as np
import pandas as pd

import gym
from machine import Machine
from GymMachEnv import MachineEnv
import matplotlib.pyplot as plt

# %%
def gen_param_array(l16_array):
    full = []
    for row in range(len(l16_array)):
        x = l16_array[row]
        arr_params = []
        
        for col in range(len(x)):
            list_params = list(params.values())[col]
            value = list_params[x[col]]
            arr_params.append(value)
        print(arr_params)
        full.append(arr_params)
    return full

def train(params_array,folder_name):
    trial = 0
    for sets in params_array:
        print("trial ",trial)
#         if trial < 6: 
#             trial+=1
#             continue
        evaluate_and_test(folder_name,trial,sets)
        trial+=1
        
def compute_avg_return(environment, policy, num_episodes):
    total_return = 0.0
    for _ in range(num_episodes):
        state = torch.Tensor(environment.reset())
        state = state.unsqueeze(0)
        episode_return = 0.0 
        while not environment.done:
            action = policy.select_action(state,True)
            next_state, reward, done, _ = environment.step(action)
            next_state = torch.Tensor(next_state)
            next_state = next_state.unsqueeze(0)
            state = next_state
            episode_return += reward
        total_return += episode_return   
    avg_return = total_return / num_episodes
    return avg_return# Evaluate the agent's policy once before training.

# %%
params = { 'eps_clipping' : [2e-05,2e-04,2e-03,2e-02],
            'gamma' : [0.8,0.9,0.95,0.99],
            'actor_lr' : [1e-04,5e-03,1e-03,1e-02],
            'critic_lr' : [1e-04,5e-03,1e-03,1e-02]}

# %%
class RolloutBuffer:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []
    

    def clear(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]


class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, has_continuous_action_space, action_std_init):
        super(ActorCritic, self).__init__()

        self.has_continuous_action_space = has_continuous_action_space


        self.actor = nn.Sequential(
                            nn.Linear(state_dim,128),
                            nn.ReLU(),
                            nn.Linear(128,64),
                            nn.ReLU(),
                            nn.Linear(64,action_dim),
                            
                            nn.Softmax(dim=-1)
                        )

        
        # critic
        self.critic = nn.Sequential(
                            nn.Linear(state_dim,128),
                            nn.ReLU(),
                            nn.Linear(128,64),
                            nn.ReLU(),
                            nn.Linear(64,1)
                    )
        
    def set_action_std(self, new_action_std):

        if self.has_continuous_action_space:
            self.action_var = torch.full((self.action_dim,), new_action_std * new_action_std)
        else:
            print("--------------------------------------------------------------------------------------------")
            print("WARNING : Calling ActorCritic::set_action_std() on discrete action space policy")
            print("--------------------------------------------------------------------------------------------")


    def forward(self):
        raise NotImplementedError
    

    def act(self, state):

        if self.has_continuous_action_space:
            action_mean = self.actor(state)
            cov_mat = torch.diag(self.action_var).unsqueeze(dim=0)
            dist = MultivariateNormal(action_mean, cov_mat)
        else:
            action_probs = self.actor(state)
            dist = Categorical(action_probs)

        action = dist.sample()
        action_logprob = dist.log_prob(action)
        
        return action.detach(), action_logprob.detach()
    

    def evaluate(self, state, action):

        if self.has_continuous_action_space:
            action_mean = self.actor(state)
            action_var = self.action_var.expand_as(action_mean)
            cov_mat = torch.diag_embed(action_var)
            dist = MultivariateNormal(action_mean, cov_mat)
            
            # for single action continuous environments
            if self.action_dim == 1:
                action = action.reshape(-1, self.action_dim)

        else:
            action_probs = self.actor(state)
            dist = Categorical(action_probs)

        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        state_values = self.critic(state)
        
        return action_logprobs, state_values, dist_entropy


class PPO:
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, has_continuous_action_space, action_std_init=0.6):

        self.has_continuous_action_space = has_continuous_action_space

        if has_continuous_action_space:
            self.action_std = action_std_init

        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.buffer = RolloutBuffer()

        self.policy = ActorCritic(state_dim, action_dim, has_continuous_action_space, action_std_init)
        self.optimizer = torch.optim.Adam([
                        {'params': self.policy.actor.parameters(), 'lr': lr_actor},
                        {'params': self.policy.critic.parameters(), 'lr': lr_critic}
                    ])

        self.policy_old = ActorCritic(state_dim, action_dim, has_continuous_action_space, action_std_init)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()


    def set_action_std(self, new_action_std):
        
        if self.has_continuous_action_space:
            self.action_std = new_action_std
            self.policy.set_action_std(new_action_std)
            self.policy_old.set_action_std(new_action_std)
        
        else:
            print("--------------------------------------------------------------------------------------------")
            print("WARNING : Calling PPO::set_action_std() on discrete action space policy")
            print("--------------------------------------------------------------------------------------------")


    def decay_action_std(self, action_std_decay_rate, min_action_std):
        print("--------------------------------------------------------------------------------------------")

        if self.has_continuous_action_space:
            self.action_std = self.action_std - action_std_decay_rate
            self.action_std = round(self.action_std, 4)
            if (self.action_std <= min_action_std):
                self.action_std = min_action_std
                print("setting actor output action_std to min_action_std : ", self.action_std)
            else:
                print("setting actor output action_std to : ", self.action_std)
            self.set_action_std(self.action_std)

        else:
            print("WARNING : Calling PPO::decay_action_std() on discrete action space policy")

        print("--------------------------------------------------------------------------------------------")


    def select_action(self, state, val=False):

        if val:
            state = torch.FloatTensor(state)
            action, action_logprob = self.policy_old.act(state)
            return action.item()

        else:
            with torch.no_grad():
                state = torch.FloatTensor(state)
                action, action_logprob = self.policy_old.act(state)
            
            self.buffer.states.append(state)
            self.buffer.actions.append(action)
            self.buffer.logprobs.append(action_logprob)

            return action.item()


    def update(self):

        # Monte Carlo estimate of returns
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.buffer.rewards), reversed(self.buffer.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
            
        # Normalizing the rewards
        rewards = torch.tensor(rewards, dtype=torch.float32)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)

        # convert list to tensor
        old_states = torch.squeeze(torch.stack(self.buffer.states, dim=0)).detach()
        old_actions = torch.squeeze(torch.stack(self.buffer.actions, dim=0)).detach()
        old_logprobs = torch.squeeze(torch.stack(self.buffer.logprobs, dim=0)).detach()

        
        # Optimize policy for K epochs
        for _ in range(self.K_epochs):

            # Evaluating old actions and values
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)

            # match state_values tensor dimensions with rewards tensor
            state_values = torch.squeeze(state_values)
            
            # Finding the ratio (pi_theta / pi_theta__old)
            ratios = torch.exp(logprobs - old_logprobs.detach())

            # Finding Surrogate Loss
            advantages = rewards - state_values.detach()   
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages

            # final loss of clipped objective PPO
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
        # Copy new weights into old policy
        self.policy_old.load_state_dict(self.policy.state_dict())

        # clear buffer
        self.buffer.clear()

# %%
l16_array = np.array(pd.read_csv('L16.txt',header=None, sep='\t'))
params_array = gen_param_array(l16_array)
params_array
# Out:
# [2e-05, 0.8, 0.0001, 0.0001]
# [2e-05, 0.9, 0.005, 0.005]
# [2e-05, 0.95, 0.001, 0.001]
# [2e-05, 0.99, 0.01, 0.01]
# [0.0002, 0.8, 0.005, 0.001]
# [0.0002, 0.9, 0.0001, 0.01]
# [0.0002, 0.95, 0.01, 0.0001]
# [0.0002, 0.99, 0.001, 0.005]
# [0.002, 0.8, 0.001, 0.01]
# [0.002, 0.9, 0.01, 0.001]
# [0.002, 0.95, 0.0001, 0.005]
# [0.002, 0.99, 0.005, 0.0001]
# [0.02, 0.8, 0.01, 0.005]
# [0.02, 0.9, 0.001, 0.0001]
# [0.02, 0.95, 0.005, 0.01]
# [0.02, 0.99, 0.0001, 0.001]
# [[2e-05, 0.8, 0.0001, 0.0001],
#  [2e-05, 0.9, 0.005, 0.005],
#  [2e-05, 0.95, 0.001, 0.001],
#  [2e-05, 0.99, 0.01, 0.01],
#  [0.0002, 0.8, 0.005, 0.001],
#  [0.0002, 0.9, 0.0001, 0.01],
#  [0.0002, 0.95, 0.01, 0.0001],
#  [0.0002, 0.99, 0.001, 0.005],
#  [0.002, 0.8, 0.001, 0.01],
#  [0.002, 0.9, 0.01, 0.001],
#  [0.002, 0.95, 0.0001, 0.005],
#  [0.002, 0.99, 0.005, 0.0001],
#  [0.02, 0.8, 0.01, 0.005],
#  [0.02, 0.9, 0.001, 0.0001],
#  [0.02, 0.95, 0.005, 0.01],
#  [0.02, 0.99, 0.0001, 0.001]]

# %%
def running_score_cal(arr,window=50):
    array = np.array(arr)
    df = pd.DataFrame(array[:,1])
    run_score = df.rolling(50,min_periods=1).mean().values.flatten().tolist()
    return run_score[-1]

# %%
def evaluate_and_test(folder_name,trial_number,params):
    max_episodes = 40000
    max_ep_len = 100
    update_timestep = max_ep_len * 4      # update policy every n timesteps
    

    machine = Machine()
    machine.curr_state = 0
    env = MachineEnv(machine)

    #Eval Env
    machine2 = Machine()
    machine2.curr_state = 0
    env2 = MachineEnv(machine2)


    gamma = params[1]
    eps_clip = params[0]
    lr_actor = params[2]
    lr_critic = params[3]
    K_epochs = 40
    
    max_score = 0

    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip, False, None)

    # printing and logging variables
    print_running_reward = 0
    print_running_episodes = 0

    log_running_reward = 0
    log_running_episodes = 0

    time_step = 0
    i_episode = 0

    tracker = []
    eval_tracker = []

    print_freq_ep = 10


    # training loop
    while i_episode <= max_episodes:

        state = env.reset()
        current_ep_reward = 0

        for t in range(1, max_ep_len+1):

            # select action with policy
            action = ppo_agent.select_action(state)
            state, reward, done, _ = env.step(action)

            # saving reward and is_terminals
            ppo_agent.buffer.rewards.append(reward)
            ppo_agent.buffer.is_terminals.append(done)

            time_step +=1
            current_ep_reward += reward

            # update PPO agent
            if time_step % update_timestep == 0:
                ppo_agent.update()

            if done:
                break

        print_running_reward += current_ep_reward
        print_running_episodes += 1

        i_episode += 1

        # printing average reward
        if i_episode % print_freq_ep == 0:

            # print average reward till last episode
            print_avg_reward = print_running_reward / print_running_episodes
            print_avg_reward = round(print_avg_reward, 2)
            tracker.append([i_episode,print_avg_reward])

            eval_score = compute_avg_return(env2,ppo_agent,20)
            eval_tracker.append([i_episode,eval_score])


            print("Episode : {} \t\t Timestep : {} \t\t Average Reward : {} \t\t Eval Score: {}".format(i_episode, time_step, print_avg_reward,eval_score))
            run_ave = np.mean(np.array(tracker)[-50:,1])
            
            if max_score < run_ave and i_episode > 100:
                torch.save(ppo_agent.policy,f'{folder_name}/trial_{trial_number}_ppo_agent.pt')
                max_score = run_ave
            
            print_running_reward = 0
            print_running_episodes = 0

    env.close()
    
    np.savetxt(f'{folder_name}/trial_{trial_number}.txt', tracker, delimiter=',',fmt='%s')
    np.savetxt(f'{folder_name}/eval_trial_{trial_number}.txt', eval_tracker, delimiter=',',fmt='%s')
    torch.save(ppo_agent.policy,f'{folder_name}/trial_{trial_number}_final_ppo_agent.pt')
    
    
    return 0

# %%
# folder_name = 'run_1'
# train(params_array,folder_name)

# %%
default_params = [2e-05, 0.95, 0.001, 0.001]
best_params = [2e-02,0.95,1e-04,1e-03]

# %%
evaluate_and_test('best',1,best_params)
# Out:
# C:\Users\overl\anaconda3\envs\env1\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.mixture.gaussian_mixture module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.mixture. Anything that cannot be imported from sklearn.mixture is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\overl\anaconda3\envs\env1\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator GaussianMixture from version 0.20.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# Episode : 10 		 Timestep : 490 		 Average Reward : 21160.0 		 Eval Score: 18860.0
# Episode : 20 		 Timestep : 881 		 Average Reward : 15430.0 		 Eval Score: 20775.0
# Episode : 30 		 Timestep : 1307 		 Average Reward : 15730.0 		 Eval Score: 18500.0
# Episode : 40 		 Timestep : 1638 		 Average Reward : 10620.0 		 Eval Score: 19540.0
# Episode : 50 		 Timestep : 2030 		 Average Reward : 14990.0 		 Eval Score: 24355.0
# Episode : 60 		 Timestep : 2686 		 Average Reward : 25380.0 		 Eval Score: 18925.0
# Episode : 70 		 Timestep : 3057 		 Average Reward : 14910.0 		 Eval Score: 23800.0
# Episode : 80 		 Timestep : 3363 		 Average Reward : 11970.0 		 Eval Score: 21390.0
# Episode : 90 		 Timestep : 3976 		 Average Reward : 29400.0 		 Eval Score: 25970.0
# Episode : 100 		 Timestep : 4369 		 Average Reward : 16200.0 		 Eval Score: 21190.0
# Episode : 110 		 Timestep : 4915 		 Average Reward : 23660.0 		 Eval Score: 20925.0
# Episode : 120 		 Timestep : 5476 		 Average Reward : 27260.0 		 Eval Score: 21865.0
# Episode : 130 		 Timestep : 5865 		 Average Reward : 17890.0 		 Eval Score: 17775.0
# Episode : 140 		 Timestep : 6269 		 Average Reward : 16790.0 		 Eval Score: 19335.0
# Episode : 150 		 Timestep : 6633 		 Average Reward : 14790.0 		 Eval Score: 21090.0
# Episode : 160 		 Timestep : 7083 		 Average Reward : 21230.0 		 Eval Score: 23230.0
# Episode : 170 		 Timestep : 7494 		 Average Reward : 21180.0 		 Eval Score: 17775.0
# Episode : 180 		 Timestep : 7944 		 Average Reward : 21470.0 		 Eval Score: 18980.0
# Episode : 190 		 Timestep : 8524 		 Average Reward : 28470.0 		 Eval Score: 16180.0
# Episode : 200 		 Timestep : 8992 		 Average Reward : 18830.0 		 Eval Score: 19580.0
# Episode : 210 		 Timestep : 9591 		 Average Reward : 28350.0 		 Eval Score: 24845.0
# Episode : 220 		 Timestep : 10167 		 Average Reward : 27940.0 		 Eval Score: 20840.0
# Episode : 230 		 Timestep : 10503 		 Average Reward : 14990.0 		 Eval Score: 24510.0
# Episode : 240 		 Timestep : 10958 		 Average Reward : 21890.0 		 Eval Score: 21540.0
# Episode : 250 		 Timestep : 11360 		 Average Reward : 18220.0 		 Eval Score: 27165.0
# Episode : 260 		 Timestep : 11744 		 Average Reward : 17290.0 		 Eval Score: 18165.0
# Episode : 270 		 Timestep : 12294 		 Average Reward : 25310.0 		 Eval Score: 21420.0
# Episode : 280 		 Timestep : 12632 		 Average Reward : 14340.0 		 Eval Score: 19475.0
# Episode : 290 		 Timestep : 13270 		 Average Reward : 31490.0 		 Eval Score: 26035.0
# Episode : 300 		 Timestep : 13750 		 Average Reward : 22390.0 		 Eval Score: 22520.0
# Episode : 310 		 Timestep : 14302 		 Average Reward : 25750.0 		 Eval Score: 21430.0
# Episode : 320 		 Timestep : 14734 		 Average Reward : 20910.0 		 Eval Score: 18020.0
# Episode : 330 		 Timestep : 15306 		 Average Reward : 27360.0 		 Eval Score: 24070.0
# Episode : 340 		 Timestep : 15737 		 Average Reward : 19740.0 		 Eval Score: 23540.0
# Episode : 350 		 Timestep : 16050 		 Average Reward : 15990.0 		 Eval Score: 19915.0
# Episode : 360 		 Timestep : 16555 		 Average Reward : 26050.0 		 Eval Score: 17135.0
# Episode : 370 		 Timestep : 17207 		 Average Reward : 34930.0 		 Eval Score: 22655.0
# Episode : 380 		 Timestep : 17661 		 Average Reward : 20230.0 		 Eval Score: 21525.0
# Episode : 390 		 Timestep : 18134 		 Average Reward : 22830.0 		 Eval Score: 23150.0
# Episode : 400 		 Timestep : 18529 		 Average Reward : 18050.0 		 Eval Score: 16505.0
# Episode : 410 		 Timestep : 18928 		 Average Reward : 21250.0 		 Eval Score: 17220.0
# Episode : 420 		 Timestep : 19397 		 Average Reward : 25160.0 		 Eval Score: 17845.0
# Episode : 430 		 Timestep : 19819 		 Average Reward : 19880.0 		 Eval Score: 21175.0
# Episode : 440 		 Timestep : 20169 		 Average Reward : 17180.0 		 Eval Score: 24540.0
# Episode : 450 		 Timestep : 20641 		 Average Reward : 22550.0 		 Eval Score: 23725.0
# Episode : 460 		 Timestep : 21204 		 Average Reward : 26000.0 		 Eval Score: 20410.0
# Episode : 470 		 Timestep : 21636 		 Average Reward : 20900.0 		 Eval Score: 21210.0
# Episode : 480 		 Timestep : 22102 		 Average Reward : 23140.0 		 Eval Score: 22930.0
# Episode : 490 		 Timestep : 22745 		 Average Reward : 30440.0 		 Eval Score: 20465.0
# Episode : 500 		 Timestep : 23018 		 Average Reward : 11910.0 		 Eval Score: 15690.0
# Episode : 510 		 Timestep : 23328 		 Average Reward : 14260.0 		 Eval Score: 24245.0
# Episode : 520 		 Timestep : 23762 		 Average Reward : 22970.0 		 Eval Score: 20780.0
# Episode : 530 		 Timestep : 24185 		 Average Reward : 20660.0 		 Eval Score: 18805.0
# Episode : 540 		 Timestep : 24467 		 Average Reward : 14500.0 		 Eval Score: 15660.0
# Episode : 550 		 Timestep : 24830 		 Average Reward : 18150.0 		 Eval Score: 18485.0
# Episode : 560 		 Timestep : 25206 		 Average Reward : 17960.0 		 Eval Score: 24845.0
# Episode : 570 		 Timestep : 25577 		 Average Reward : 18420.0 		 Eval Score: 23060.0
# Episode : 580 		 Timestep : 26081 		 Average Reward : 25180.0 		 Eval Score: 20520.0
# Episode : 590 		 Timestep : 26510 		 Average Reward : 19450.0 		 Eval Score: 22805.0
# Episode : 600 		 Timestep : 27016 		 Average Reward : 25270.0 		 Eval Score: 21210.0
# Episode : 610 		 Timestep : 27469 		 Average Reward : 22400.0 		 Eval Score: 21480.0
# Episode : 620 		 Timestep : 28040 		 Average Reward : 30380.0 		 Eval Score: 11550.0
# Episode : 630 		 Timestep : 28417 		 Average Reward : 17480.0 		 Eval Score: 19225.0
# Episode : 640 		 Timestep : 28893 		 Average Reward : 24470.0 		 Eval Score: 18150.0
# Episode : 650 		 Timestep : 29266 		 Average Reward : 16630.0 		 Eval Score: 18045.0
# Episode : 660 		 Timestep : 29522 		 Average Reward : 11100.0 		 Eval Score: 26025.0
# Episode : 670 		 Timestep : 30080 		 Average Reward : 26580.0 		 Eval Score: 15180.0
# Episode : 680 		 Timestep : 30321 		 Average Reward : 11190.0 		 Eval Score: 21370.0
# Episode : 690 		 Timestep : 30600 		 Average Reward : 14360.0 		 Eval Score: 21015.0
# Episode : 700 		 Timestep : 30884 		 Average Reward : 13250.0 		 Eval Score: 21145.0
# Episode : 710 		 Timestep : 31151 		 Average Reward : 12630.0 		 Eval Score: 22185.0
# Episode : 720 		 Timestep : 31690 		 Average Reward : 28640.0 		 Eval Score: 13840.0
# Episode : 730 		 Timestep : 32132 		 Average Reward : 24060.0 		 Eval Score: 23400.0
# Episode : 740 		 Timestep : 32804 		 Average Reward : 36100.0 		 Eval Score: 17905.0
# Episode : 750 		 Timestep : 33237 		 Average Reward : 23890.0 		 Eval Score: 22110.0
# Episode : 760 		 Timestep : 33689 		 Average Reward : 21940.0 		 Eval Score: 20795.0
# Episode : 770 		 Timestep : 34143 		 Average Reward : 24730.0 		 Eval Score: 20580.0
# Episode : 780 		 Timestep : 34440 		 Average Reward : 15790.0 		 Eval Score: 16855.0
# Episode : 790 		 Timestep : 34849 		 Average Reward : 21220.0 		 Eval Score: 18305.0
# Episode : 800 		 Timestep : 35247 		 Average Reward : 19420.0 		 Eval Score: 21635.0
# Episode : 810 		 Timestep : 35672 		 Average Reward : 19710.0 		 Eval Score: 26675.0
# Episode : 820 		 Timestep : 36038 		 Average Reward : 17850.0 		 Eval Score: 22185.0
# Episode : 830 		 Timestep : 36366 		 Average Reward : 15070.0 		 Eval Score: 23100.0
# Episode : 840 		 Timestep : 36827 		 Average Reward : 23600.0 		 Eval Score: 22780.0
# Episode : 850 		 Timestep : 37257 		 Average Reward : 20620.0 		 Eval Score: 25080.0
# Episode : 860 		 Timestep : 37546 		 Average Reward : 14540.0 		 Eval Score: 17775.0
# Episode : 870 		 Timestep : 37810 		 Average Reward : 11680.0 		 Eval Score: 20935.0
# Episode : 880 		 Timestep : 38345 		 Average Reward : 27420.0 		 Eval Score: 21495.0
# Episode : 890 		 Timestep : 38672 		 Average Reward : 16480.0 		 Eval Score: 13340.0
# Episode : 900 		 Timestep : 38956 		 Average Reward : 13400.0 		 Eval Score: 20730.0
# Episode : 910 		 Timestep : 39401 		 Average Reward : 22700.0 		 Eval Score: 20925.0
# Episode : 920 		 Timestep : 39654 		 Average Reward : 13220.0 		 Eval Score: 12410.0
# Episode : 930 		 Timestep : 39958 		 Average Reward : 15760.0 		 Eval Score: 24700.0
# Episode : 940 		 Timestep : 40402 		 Average Reward : 22490.0 		 Eval Score: 18850.0
# Episode : 950 		 Timestep : 40921 		 Average Reward : 27040.0 		 Eval Score: 23115.0
# Episode : 960 		 Timestep : 41487 		 Average Reward : 30460.0 		 Eval Score: 23005.0
# Episode : 970 		 Timestep : 41964 		 Average Reward : 27320.0 		 Eval Score: 19255.0
# Episode : 980 		 Timestep : 42460 		 Average Reward : 24940.0 		 Eval Score: 26000.0
# Episode : 990 		 Timestep : 42956 		 Average Reward : 26120.0 		 Eval Score: 23450.0
# Episode : 1000 		 Timestep : 43453 		 Average Reward : 25190.0 		 Eval Score: 16705.0
# Episode : 1010 		 Timestep : 43729 		 Average Reward : 13140.0 		 Eval Score: 18465.0
# Episode : 1020 		 Timestep : 44203 		 Average Reward : 24540.0 		 Eval Score: 20310.0
# Episode : 1030 		 Timestep : 44498 		 Average Reward : 12190.0 		 Eval Score: 27680.0
# Episode : 1040 		 Timestep : 44925 		 Average Reward : 20790.0 		 Eval Score: 19760.0
# Episode : 1050 		 Timestep : 45410 		 Average Reward : 25490.0 		 Eval Score: 22150.0
# Episode : 1060 		 Timestep : 45892 		 Average Reward : 23480.0 		 Eval Score: 20170.0
# Episode : 1070 		 Timestep : 46376 		 Average Reward : 26070.0 		 Eval Score: 25350.0
# Episode : 1080 		 Timestep : 46634 		 Average Reward : 12360.0 		 Eval Score: 21395.0
# Episode : 1090 		 Timestep : 47117 		 Average Reward : 26420.0 		 Eval Score: 19040.0
# Episode : 1100 		 Timestep : 47436 		 Average Reward : 15350.0 		 Eval Score: 22110.0
# Episode : 1110 		 Timestep : 47750 		 Average Reward : 16500.0 		 Eval Score: 17165.0
# Episode : 1120 		 Timestep : 48047 		 Average Reward : 15880.0 		 Eval Score: 13225.0
# Episode : 1130 		 Timestep : 48508 		 Average Reward : 23440.0 		 Eval Score: 22020.0
# Episode : 1140 		 Timestep : 48740 		 Average Reward : 9910.0 		 Eval Score: 21820.0
# Episode : 1150 		 Timestep : 49091 		 Average Reward : 17630.0 		 Eval Score: 21080.0
# Episode : 1160 		 Timestep : 49622 		 Average Reward : 27410.0 		 Eval Score: 15790.0
# Episode : 1170 		 Timestep : 49946 		 Average Reward : 18850.0 		 Eval Score: 23150.0
# Episode : 1180 		 Timestep : 50443 		 Average Reward : 25960.0 		 Eval Score: 17560.0
# Episode : 1190 		 Timestep : 50841 		 Average Reward : 22630.0 		 Eval Score: 16645.0
# Episode : 1200 		 Timestep : 51151 		 Average Reward : 14340.0 		 Eval Score: 19605.0
# Episode : 1210 		 Timestep : 51559 		 Average Reward : 19720.0 		 Eval Score: 17300.0
# Episode : 1220 		 Timestep : 51980 		 Average Reward : 21930.0 		 Eval Score: 22705.0
# Episode : 1230 		 Timestep : 52365 		 Average Reward : 19790.0 		 Eval Score: 16595.0
# Episode : 1240 		 Timestep : 52773 		 Average Reward : 19980.0 		 Eval Score: 26640.0
# Episode : 1250 		 Timestep : 53137 		 Average Reward : 19930.0 		 Eval Score: 16505.0
# Episode : 1260 		 Timestep : 53546 		 Average Reward : 22870.0 		 Eval Score: 23170.0
# Episode : 1270 		 Timestep : 53921 		 Average Reward : 17410.0 		 Eval Score: 20480.0
# Episode : 1280 		 Timestep : 54427 		 Average Reward : 24980.0 		 Eval Score: 22765.0
# Episode : 1290 		 Timestep : 54932 		 Average Reward : 26230.0 		 Eval Score: 16405.0
# Episode : 1300 		 Timestep : 55278 		 Average Reward : 18150.0 		 Eval Score: 19790.0
# Episode : 1310 		 Timestep : 55791 		 Average Reward : 26620.0 		 Eval Score: 22010.0
# Episode : 1320 		 Timestep : 56240 		 Average Reward : 24380.0 		 Eval Score: 22910.0
# Episode : 1960 		 Timestep : 83028 		 Average Reward : 20240.0 		 Eval Score: 23055.0
# Episode : 1970 		 Timestep : 83390 		 Average Reward : 17720.0 		 Eval Score: 20575.0
# Episode : 1980 		 Timestep : 83820 		 Average Reward : 23970.0 		 Eval Score: 19705.0
# Episode : 1990 		 Timestep : 84165 		 Average Reward : 17720.0 		 Eval Score: 25030.0
# Episode : 2000 		 Timestep : 84619 		 Average Reward : 22870.0 		 Eval Score: 22905.0
# Episode : 2010 		 Timestep : 84980 		 Average Reward : 17070.0 		 Eval Score: 27220.0
# Episode : 2020 		 Timestep : 85412 		 Average Reward : 22050.0 		 Eval Score: 23940.0
# Episode : 2030 		 Timestep : 85797 		 Average Reward : 19850.0 		 Eval Score: 27820.0
# Episode : 2040 		 Timestep : 86178 		 Average Reward : 20230.0 		 Eval Score: 22000.0
# Episode : 2050 		 Timestep : 86517 		 Average Reward : 15810.0 		 Eval Score: 20330.0
# Episode : 2060 		 Timestep : 87030 		 Average Reward : 28550.0 		 Eval Score: 18375.0
# Episode : 2070 		 Timestep : 87243 		 Average Reward : 10550.0 		 Eval Score: 22085.0
# Episode : 2080 		 Timestep : 87732 		 Average Reward : 26100.0 		 Eval Score: 22030.0
# Episode : 2090 		 Timestep : 88051 		 Average Reward : 13520.0 		 Eval Score: 28465.0
# Episode : 2100 		 Timestep : 88560 		 Average Reward : 26900.0 		 Eval Score: 19605.0
# Episode : 2110 		 Timestep : 88946 		 Average Reward : 20860.0 		 Eval Score: 22840.0
# Episode : 2120 		 Timestep : 89246 		 Average Reward : 13830.0 		 Eval Score: 17970.0
# Episode : 2130 		 Timestep : 89655 		 Average Reward : 21260.0 		 Eval Score: 23830.0
# Episode : 2140 		 Timestep : 90097 		 Average Reward : 22150.0 		 Eval Score: 24695.0
# Episode : 2150 		 Timestep : 90502 		 Average Reward : 18490.0 		 Eval Score: 18315.0
# Episode : 2160 		 Timestep : 91010 		 Average Reward : 27880.0 		 Eval Score: 13340.0
# Episode : 2170 		 Timestep : 91416 		 Average Reward : 22990.0 		 Eval Score: 27355.0
# Episode : 2180 		 Timestep : 91927 		 Average Reward : 27510.0 		 Eval Score: 25965.0
# Episode : 2190 		 Timestep : 92559 		 Average Reward : 34650.0 		 Eval Score: 15190.0
# Episode : 2200 		 Timestep : 92930 		 Average Reward : 20590.0 		 Eval Score: 22370.0
# Episode : 2210 		 Timestep : 93078 		 Average Reward : 6590.0 		 Eval Score: 19955.0
# Episode : 2220 		 Timestep : 93493 		 Average Reward : 22370.0 		 Eval Score: 18315.0
# Episode : 2230 		 Timestep : 93931 		 Average Reward : 22920.0 		 Eval Score: 21980.0
# Episode : 2240 		 Timestep : 94465 		 Average Reward : 28040.0 		 Eval Score: 17955.0
# Episode : 2250 		 Timestep : 94907 		 Average Reward : 22900.0 		 Eval Score: 21410.0
# Episode : 2260 		 Timestep : 95605 		 Average Reward : 36760.0 		 Eval Score: 30680.0
# Episode : 2270 		 Timestep : 96010 		 Average Reward : 19830.0 		 Eval Score: 21385.0
# Episode : 2280 		 Timestep : 96342 		 Average Reward : 15340.0 		 Eval Score: 25145.0
# Episode : 2290 		 Timestep : 96703 		 Average Reward : 17950.0 		 Eval Score: 21615.0
# Episode : 2300 		 Timestep : 97189 		 Average Reward : 25620.0 		 Eval Score: 25000.0
# Episode : 2310 		 Timestep : 97607 		 Average Reward : 21030.0 		 Eval Score: 13510.0
# Episode : 2320 		 Timestep : 98090 		 Average Reward : 26190.0 		 Eval Score: 19620.0
# Episode : 2330 		 Timestep : 98626 		 Average Reward : 27020.0 		 Eval Score: 29415.0
# Episode : 2340 		 Timestep : 99142 		 Average Reward : 28040.0 		 Eval Score: 28905.0
# Episode : 2350 		 Timestep : 99530 		 Average Reward : 20760.0 		 Eval Score: 24815.0
# Episode : 2360 		 Timestep : 100012 		 Average Reward : 26050.0 		 Eval Score: 19120.0
# Episode : 2370 		 Timestep : 100432 		 Average Reward : 22730.0 		 Eval Score: 13385.0
# Episode : 2380 		 Timestep : 100826 		 Average Reward : 19890.0 		 Eval Score: 15025.0
# Episode : 2390 		 Timestep : 101298 		 Average Reward : 24720.0 		 Eval Score: 17950.0
# Episode : 2400 		 Timestep : 101746 		 Average Reward : 22640.0 		 Eval Score: 20295.0
# Episode : 2410 		 Timestep : 102264 		 Average Reward : 28990.0 		 Eval Score: 23880.0
# Episode : 2420 		 Timestep : 102766 		 Average Reward : 27690.0 		 Eval Score: 21535.0
# Episode : 2430 		 Timestep : 103248 		 Average Reward : 24250.0 		 Eval Score: 20745.0
# Episode : 2440 		 Timestep : 103758 		 Average Reward : 27610.0 		 Eval Score: 16880.0
# Episode : 2450 		 Timestep : 103968 		 Average Reward : 10440.0 		 Eval Score: 32565.0
# Episode : 2460 		 Timestep : 104292 		 Average Reward : 16530.0 		 Eval Score: 31750.0
# Episode : 2470 		 Timestep : 104682 		 Average Reward : 18600.0 		 Eval Score: 29400.0
# Episode : 2480 		 Timestep : 105135 		 Average Reward : 24360.0 		 Eval Score: 24015.0
# Episode : 2490 		 Timestep : 105405 		 Average Reward : 13470.0 		 Eval Score: 22145.0
# Episode : 2500 		 Timestep : 105838 		 Average Reward : 20640.0 		 Eval Score: 25895.0
# Episode : 2510 		 Timestep : 106340 		 Average Reward : 24700.0 		 Eval Score: 26225.0
# Episode : 2520 		 Timestep : 106839 		 Average Reward : 27680.0 		 Eval Score: 32555.0
# Episode : 2530 		 Timestep : 107157 		 Average Reward : 15940.0 		 Eval Score: 19015.0
# Episode : 2540 		 Timestep : 107557 		 Average Reward : 19420.0 		 Eval Score: 20140.0
# Episode : 2550 		 Timestep : 107902 		 Average Reward : 16730.0 		 Eval Score: 17470.0
# Episode : 2560 		 Timestep : 108364 		 Average Reward : 24760.0 		 Eval Score: 24600.0
# Episode : 2570 		 Timestep : 108820 		 Average Reward : 24910.0 		 Eval Score: 22170.0
# Episode : 2580 		 Timestep : 109345 		 Average Reward : 28130.0 		 Eval Score: 17605.0
# Episode : 2590 		 Timestep : 109818 		 Average Reward : 25300.0 		 Eval Score: 16900.0
# Episode : 2600 		 Timestep : 110448 		 Average Reward : 32070.0 		 Eval Score: 16450.0
# Episode : 2610 		 Timestep : 111004 		 Average Reward : 29860.0 		 Eval Score: 31805.0
# Episode : 2620 		 Timestep : 111449 		 Average Reward : 22660.0 		 Eval Score: 20290.0
# Episode : 2630 		 Timestep : 111821 		 Average Reward : 19250.0 		 Eval Score: 22350.0
# Episode : 2640 		 Timestep : 112183 		 Average Reward : 19490.0 		 Eval Score: 25225.0
# Episode : 2650 		 Timestep : 112683 		 Average Reward : 26840.0 		 Eval Score: 17925.0
# Episode : 2660 		 Timestep : 113243 		 Average Reward : 29000.0 		 Eval Score: 23895.0
# Episode : 2670 		 Timestep : 113472 		 Average Reward : 11200.0 		 Eval Score: 25500.0
# Episode : 2680 		 Timestep : 113939 		 Average Reward : 27150.0 		 Eval Score: 23165.0
# Episode : 2690 		 Timestep : 114228 		 Average Reward : 15310.0 		 Eval Score: 26050.0
# Episode : 2700 		 Timestep : 114639 		 Average Reward : 22920.0 		 Eval Score: 24005.0
# Episode : 2710 		 Timestep : 115212 		 Average Reward : 30850.0 		 Eval Score: 25990.0
# Episode : 2720 		 Timestep : 115704 		 Average Reward : 28050.0 		 Eval Score: 20210.0
# Episode : 2730 		 Timestep : 116146 		 Average Reward : 22050.0 		 Eval Score: 16050.0
# Episode : 2740 		 Timestep : 116645 		 Average Reward : 25720.0 		 Eval Score: 26435.0
# Episode : 2750 		 Timestep : 117130 		 Average Reward : 26170.0 		 Eval Score: 19075.0
# Episode : 2760 		 Timestep : 117506 		 Average Reward : 19350.0 		 Eval Score: 26915.0
# Episode : 2770 		 Timestep : 118046 		 Average Reward : 28280.0 		 Eval Score: 23280.0
# Episode : 2780 		 Timestep : 118623 		 Average Reward : 30090.0 		 Eval Score: 25765.0
# Episode : 2790 		 Timestep : 118927 		 Average Reward : 14020.0 		 Eval Score: 27990.0
# Episode : 2800 		 Timestep : 119454 		 Average Reward : 27900.0 		 Eval Score: 23230.0
# Episode : 2810 		 Timestep : 119890 		 Average Reward : 23780.0 		 Eval Score: 22045.0
# Episode : 2820 		 Timestep : 120210 		 Average Reward : 14900.0 		 Eval Score: 24075.0
# Episode : 2830 		 Timestep : 120578 		 Average Reward : 18890.0 		 Eval Score: 19190.0
# Episode : 2840 		 Timestep : 121029 		 Average Reward : 24290.0 		 Eval Score: 25440.0
# Episode : 2850 		 Timestep : 121382 		 Average Reward : 19680.0 		 Eval Score: 24750.0
# Episode : 2860 		 Timestep : 121916 		 Average Reward : 26690.0 		 Eval Score: 25140.0
# Episode : 2870 		 Timestep : 122233 		 Average Reward : 15040.0 		 Eval Score: 28010.0
# Episode : 2880 		 Timestep : 122819 		 Average Reward : 30660.0 		 Eval Score: 17240.0
# Episode : 2890 		 Timestep : 123093 		 Average Reward : 14260.0 		 Eval Score: 17175.0
# Episode : 3530 		 Timestep : 152056 		 Average Reward : 20150.0 		 Eval Score: 26035.0
# Episode : 3540 		 Timestep : 152490 		 Average Reward : 22620.0 		 Eval Score: 25450.0
# Episode : 3550 		 Timestep : 152962 		 Average Reward : 24740.0 		 Eval Score: 30725.0
# Episode : 3560 		 Timestep : 153452 		 Average Reward : 26530.0 		 Eval Score: 20995.0
# Episode : 3570 		 Timestep : 153718 		 Average Reward : 14870.0 		 Eval Score: 23730.0
# Episode : 3580 		 Timestep : 154270 		 Average Reward : 28610.0 		 Eval Score: 22490.0
# Episode : 3590 		 Timestep : 154628 		 Average Reward : 18330.0 		 Eval Score: 21360.0
# Episode : 3600 		 Timestep : 155177 		 Average Reward : 29330.0 		 Eval Score: 21495.0
# Episode : 3610 		 Timestep : 155690 		 Average Reward : 27860.0 		 Eval Score: 25125.0
# Episode : 3620 		 Timestep : 156114 		 Average Reward : 22350.0 		 Eval Score: 24510.0
# Episode : 3630 		 Timestep : 156657 		 Average Reward : 29670.0 		 Eval Score: 22100.0
# Episode : 3640 		 Timestep : 157012 		 Average Reward : 19030.0 		 Eval Score: 24350.0
# Episode : 3650 		 Timestep : 157385 		 Average Reward : 18240.0 		 Eval Score: 19600.0
# Episode : 3660 		 Timestep : 157724 		 Average Reward : 17210.0 		 Eval Score: 18780.0
# Episode : 3670 		 Timestep : 158218 		 Average Reward : 27770.0 		 Eval Score: 21480.0
# Episode : 3680 		 Timestep : 158905 		 Average Reward : 36410.0 		 Eval Score: 34860.0
# Episode : 3690 		 Timestep : 159272 		 Average Reward : 18990.0 		 Eval Score: 23125.0
# Episode : 3700 		 Timestep : 159705 		 Average Reward : 22010.0 		 Eval Score: 22820.0
# Episode : 3710 		 Timestep : 160104 		 Average Reward : 19010.0 		 Eval Score: 28480.0
# Episode : 3720 		 Timestep : 160440 		 Average Reward : 17560.0 		 Eval Score: 26890.0
# Episode : 3730 		 Timestep : 160707 		 Average Reward : 12410.0 		 Eval Score: 34390.0
# Episode : 3740 		 Timestep : 161214 		 Average Reward : 26490.0 		 Eval Score: 22555.0
# Episode : 3750 		 Timestep : 161800 		 Average Reward : 32700.0 		 Eval Score: 22475.0
# Episode : 3760 		 Timestep : 162407 		 Average Reward : 33920.0 		 Eval Score: 24265.0
# Episode : 3770 		 Timestep : 162840 		 Average Reward : 24710.0 		 Eval Score: 30340.0
# Episode : 3780 		 Timestep : 163387 		 Average Reward : 26940.0 		 Eval Score: 22100.0
# Episode : 3790 		 Timestep : 163744 		 Average Reward : 16740.0 		 Eval Score: 18350.0
# Episode : 3800 		 Timestep : 164031 		 Average Reward : 14470.0 		 Eval Score: 26875.0
# Episode : 3810 		 Timestep : 164592 		 Average Reward : 29310.0 		 Eval Score: 26770.0
# Episode : 3820 		 Timestep : 165166 		 Average Reward : 29160.0 		 Eval Score: 20270.0
# Episode : 3830 		 Timestep : 165454 		 Average Reward : 15300.0 		 Eval Score: 26710.0
# Episode : 3840 		 Timestep : 165910 		 Average Reward : 23390.0 		 Eval Score: 26170.0
# Episode : 39090 		 Timestep : 1784305 		 Average Reward : 21500.0 		 Eval Score: 20060.0
# Episode : 39100 		 Timestep : 1784648 		 Average Reward : 19410.0 		 Eval Score: 21210.0
# Episode : 39110 		 Timestep : 1785179 		 Average Reward : 28240.0 		 Eval Score: 24455.0
# Episode : 39120 		 Timestep : 1785728 		 Average Reward : 31720.0 		 Eval Score: 25935.0
# Episode : 39130 		 Timestep : 1786130 		 Average Reward : 21490.0 		 Eval Score: 25500.0
# Episode : 39140 		 Timestep : 1786760 		 Average Reward : 34150.0 		 Eval Score: 20530.0
# Episode : 39150 		 Timestep : 1787144 		 Average Reward : 20290.0 		 Eval Score: 20950.0
# Episode : 39160 		 Timestep : 1787681 		 Average Reward : 30590.0 		 Eval Score: 28325.0
# Episode : 39170 		 Timestep : 1788047 		 Average Reward : 20080.0 		 Eval Score: 23030.0
# Episode : 39180 		 Timestep : 1788551 		 Average Reward : 27910.0 		 Eval Score: 29660.0
# Episode : 39190 		 Timestep : 1788963 		 Average Reward : 23020.0 		 Eval Score: 27295.0
# Episode : 39200 		 Timestep : 1789497 		 Average Reward : 30620.0 		 Eval Score: 29470.0
# Episode : 39210 		 Timestep : 1789931 		 Average Reward : 22620.0 		 Eval Score: 27540.0
# Episode : 39220 		 Timestep : 1790383 		 Average Reward : 24300.0 		 Eval Score: 18150.0
# Episode : 39230 		 Timestep : 1790792 		 Average Reward : 21210.0 		 Eval Score: 18380.0
# Episode : 39240 		 Timestep : 1791293 		 Average Reward : 25390.0 		 Eval Score: 25150.0
# Episode : 39250 		 Timestep : 1791781 		 Average Reward : 28350.0 		 Eval Score: 20115.0
# Episode : 39260 		 Timestep : 1792185 		 Average Reward : 21610.0 		 Eval Score: 25790.0
# Episode : 39270 		 Timestep : 1792699 		 Average Reward : 26490.0 		 Eval Score: 22960.0
# Episode : 39280 		 Timestep : 1792985 		 Average Reward : 13470.0 		 Eval Score: 26325.0
# Episode : 39290 		 Timestep : 1793553 		 Average Reward : 33170.0 		 Eval Score: 26225.0
# Episode : 39300 		 Timestep : 1793977 		 Average Reward : 22080.0 		 Eval Score: 28450.0
# Episode : 39310 		 Timestep : 1794536 		 Average Reward : 32590.0 		 Eval Score: 34285.0
# Episode : 39320 		 Timestep : 1795108 		 Average Reward : 30710.0 		 Eval Score: 30190.0
# Episode : 39330 		 Timestep : 1795486 		 Average Reward : 19900.0 		 Eval Score: 20390.0
# Episode : 39340 		 Timestep : 1795915 		 Average Reward : 21850.0 		 Eval Score: 32390.0
# Episode : 39350 		 Timestep : 1796485 		 Average Reward : 28970.0 		 Eval Score: 28735.0
# Episode : 39360 		 Timestep : 1797000 		 Average Reward : 30250.0 		 Eval Score: 18200.0
# Episode : 39370 		 Timestep : 1797424 		 Average Reward : 23150.0 		 Eval Score: 23925.0
# Episode : 39380 		 Timestep : 1797888 		 Average Reward : 25680.0 		 Eval Score: 16850.0
# Episode : 39390 		 Timestep : 1798340 		 Average Reward : 24250.0 		 Eval Score: 25855.0
# Episode : 39400 		 Timestep : 1798925 		 Average Reward : 33620.0 		 Eval Score: 28780.0
# Episode : 39410 		 Timestep : 1799322 		 Average Reward : 20900.0 		 Eval Score: 39600.0
# Episode : 39420 		 Timestep : 1799605 		 Average Reward : 13790.0 		 Eval Score: 28060.0
# Episode : 39430 		 Timestep : 1800250 		 Average Reward : 36450.0 		 Eval Score: 16915.0
# Episode : 39440 		 Timestep : 1800631 		 Average Reward : 20180.0 		 Eval Score: 22775.0
# Episode : 39450 		 Timestep : 1801134 		 Average Reward : 27400.0 		 Eval Score: 23810.0
# Episode : 39460 		 Timestep : 1801571 		 Average Reward : 23020.0 		 Eval Score: 26590.0
# Episode : 39470 		 Timestep : 1802109 		 Average Reward : 29230.0 		 Eval Score: 32975.0
# Episode : 39480 		 Timestep : 1802737 		 Average Reward : 35610.0 		 Eval Score: 26950.0
# Episode : 39490 		 Timestep : 1803253 		 Average Reward : 31180.0 		 Eval Score: 26235.0
# Episode : 39500 		 Timestep : 1803814 		 Average Reward : 32550.0 		 Eval Score: 19405.0
# Episode : 39510 		 Timestep : 1804090 		 Average Reward : 14600.0 		 Eval Score: 18515.0
# Episode : 39520 		 Timestep : 1804621 		 Average Reward : 29660.0 		 Eval Score: 29540.0
# Episode : 39530 		 Timestep : 1805075 		 Average Reward : 24000.0 		 Eval Score: 22685.0
# Episode : 39540 		 Timestep : 1805544 		 Average Reward : 24290.0 		 Eval Score: 27825.0
# Episode : 39550 		 Timestep : 1805952 		 Average Reward : 20800.0 		 Eval Score: 30620.0
# Episode : 39560 		 Timestep : 1806449 		 Average Reward : 26520.0 		 Eval Score: 24275.0
# Episode : 39570 		 Timestep : 1807016 		 Average Reward : 32050.0 		 Eval Score: 17040.0
# Episode : 39580 		 Timestep : 1807478 		 Average Reward : 26710.0 		 Eval Score: 24935.0
# Episode : 39590 		 Timestep : 1808014 		 Average Reward : 29890.0 		 Eval Score: 19680.0
# Episode : 39600 		 Timestep : 1808476 		 Average Reward : 26840.0 		 Eval Score: 24415.0
# Episode : 39610 		 Timestep : 1808814 		 Average Reward : 17950.0 		 Eval Score: 28950.0
# Episode : 39620 		 Timestep : 1809055 		 Average Reward : 10920.0 		 Eval Score: 16735.0
# Episode : 39630 		 Timestep : 1809597 		 Average Reward : 29800.0 		 Eval Score: 26790.0
# Episode : 39640 		 Timestep : 1809904 		 Average Reward : 13430.0 		 Eval Score: 31680.0
# Episode : 39650 		 Timestep : 1810434 		 Average Reward : 29430.0 		 Eval Score: 21855.0
# Episode : 39660 		 Timestep : 1811059 		 Average Reward : 33410.0 		 Eval Score: 29945.0
# Episode : 39670 		 Timestep : 1811425 		 Average Reward : 19250.0 		 Eval Score: 28685.0
# Episode : 39680 		 Timestep : 1811981 		 Average Reward : 29570.0 		 Eval Score: 29800.0
# Episode : 39690 		 Timestep : 1812473 		 Average Reward : 27270.0 		 Eval Score: 23305.0
# Episode : 39700 		 Timestep : 1813006 		 Average Reward : 28380.0 		 Eval Score: 15835.0
# Episode : 39710 		 Timestep : 1813716 		 Average Reward : 37630.0 		 Eval Score: 18970.0
# Episode : 39720 		 Timestep : 1814120 		 Average Reward : 22080.0 		 Eval Score: 32450.0
# Episode : 39730 		 Timestep : 1814698 		 Average Reward : 32960.0 		 Eval Score: 26875.0
# Episode : 39740 		 Timestep : 1815286 		 Average Reward : 32230.0 		 Eval Score: 23865.0
# Episode : 39750 		 Timestep : 1815846 		 Average Reward : 30200.0 		 Eval Score: 27945.0
# Episode : 39760 		 Timestep : 1816370 		 Average Reward : 30600.0 		 Eval Score: 28165.0
# Episode : 39770 		 Timestep : 1816668 		 Average Reward : 14360.0 		 Eval Score: 23525.0
# Episode : 39780 		 Timestep : 1817258 		 Average Reward : 33230.0 		 Eval Score: 24745.0
# Episode : 39790 		 Timestep : 1817659 		 Average Reward : 21270.0 		 Eval Score: 29890.0
# Episode : 39800 		 Timestep : 1818007 		 Average Reward : 19270.0 		 Eval Score: 28110.0
# Episode : 39810 		 Timestep : 1818380 		 Average Reward : 21080.0 		 Eval Score: 27860.0
# Episode : 39820 		 Timestep : 1818990 		 Average Reward : 32980.0 		 Eval Score: 24600.0
# Episode : 39830 		 Timestep : 1819524 		 Average Reward : 29980.0 		 Eval Score: 33195.0
# Episode : 39840 		 Timestep : 1819838 		 Average Reward : 15380.0 		 Eval Score: 26655.0
# Episode : 39850 		 Timestep : 1820479 		 Average Reward : 36490.0 		 Eval Score: 19785.0
# Episode : 39860 		 Timestep : 1821040 		 Average Reward : 32480.0 		 Eval Score: 22345.0
# Episode : 39870 		 Timestep : 1821553 		 Average Reward : 26630.0 		 Eval Score: 24805.0
# Episode : 39880 		 Timestep : 1822108 		 Average Reward : 30060.0 		 Eval Score: 23030.0
# Episode : 39890 		 Timestep : 1822441 		 Average Reward : 18300.0 		 Eval Score: 24940.0
# Episode : 39900 		 Timestep : 1822847 		 Average Reward : 22500.0 		 Eval Score: 30740.0
# Episode : 39910 		 Timestep : 1823435 		 Average Reward : 31190.0 		 Eval Score: 23380.0
# Episode : 39920 		 Timestep : 1823995 		 Average Reward : 31260.0 		 Eval Score: 24815.0
# Episode : 39930 		 Timestep : 1824441 		 Average Reward : 25070.0 		 Eval Score: 29430.0
# Episode : 39940 		 Timestep : 1824946 		 Average Reward : 28300.0 		 Eval Score: 21695.0
# Episode : 39950 		 Timestep : 1825385 		 Average Reward : 21530.0 		 Eval Score: 25270.0
# Episode : 39960 		 Timestep : 1825978 		 Average Reward : 34280.0 		 Eval Score: 27800.0
# Episode : 39970 		 Timestep : 1826586 		 Average Reward : 32230.0 		 Eval Score: 28335.0
# Episode : 39980 		 Timestep : 1827039 		 Average Reward : 24500.0 		 Eval Score: 21985.0
# Episode : 39990 		 Timestep : 1827416 		 Average Reward : 18360.0 		 Eval Score: 34900.0
# Episode : 40000 		 Timestep : 1827880 		 Average Reward : 26350.0 		 Eval Score: 20725.0
# 0
